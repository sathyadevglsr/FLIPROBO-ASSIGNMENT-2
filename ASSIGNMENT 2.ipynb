# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Analyst')

# %%
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Banglore")

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

experience_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
#creating DataFrame 

df= pd.DataFrame({"Job Title":job_title,"Job Location":job_location,"Company Name":company_name,"Experience Required":experience_required})
df
# Out:
#                         Job Title                        Job Location  \
# 0                    Data Analyst                 Bangalore/Bengaluru
# 1                    Data Analyst                 Bangalore/Bengaluru
# 2                    Data Analyst                 Bangalore/Bengaluru
# 3                Sr. Data Analyst                 Bangalore/Bengaluru
# 4          Senior Data Analyst II                 Bangalore/Bengaluru
# 5  Senior Data Management Analyst                 Bangalore/Bengaluru
# 6                    Data Analyst                 Bangalore/Bengaluru
# 7       Sr Data Analyst - Tableau                 Bangalore/Bengaluru
# 8            Project Data Analyst                 Bangalore/Bengaluru
# 9  Data Analyst, Business Analyst  Bangalore/Bengaluru(HSR Layout +1)
#
#                                      Company Name  \
# 0                                   Shell Pvt Ltd
# 1                                   Shell Pvt Ltd
# ...

# %% [markdown]
# Q2:Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
location1 = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location1.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title1=[]
job_location1=[]
company_name1=[]

# %%
title_tags1=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags1[0:10]:
    title=i.text
    job_title1.append(title)

location_tags1=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags1[0:10]:
    location=i.text
    job_location1.append(location)
    
company_tags1=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags1[0:10]:
    company=i.text
    company_name1.append(company)

# %%
#creating DataFrame 
df1= pd.DataFrame({"Job Title":job_title1,"Job Location":job_location1,"Company Name":company_name1})
df1
# Out:
#                                           Job Title  \
# 0                  Analystics & Modeling Specialist
# 1                                    Data Scientist
# 2                                    Data Scientist
# 3      Data & Analytics Lead, Geo Analytics - GAMMA
# 4                Weather and Climate Data Scientist
# 5                              Manager-Data Science
# 6                                    Data Scientist
# 7                               Data Scientist - II
# 8                             Senior Data Scientist
# 9  ACN - Applied Intelligence - Data Scientist - 09
#
#                                         Job Location             Company Name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...              Tata Nexarc
# 2                  Bangalore/Bengaluru, Nagpur, Pune            Tech Mahindra
# 3                                Bangalore/Bengaluru  Boston Consulting Group
# ...

# %% [markdown]
# Q3. You have to scrape data for "Data scientist" in location "Delhi/NCR" with salary filter of 3-6 lakhs.

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

search1=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search1.click()

# %%
loc= driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/i")
loc.click()

# %%
salary= driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]")
salary.click()

# %%
job_title2=[]
job_location2=[]
company_name2=[]
experience_required2=[]

# %%
title_tags2=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags2[0:10]:
    title=i.text
    job_title2.append(title)

location_tags2=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags2[0:10]:
    location=i.text
    job_location2.append(location)
    
company_tags2=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags2[0:10]:
    company=i.text
    company_name2.append(company)

experience_tags2=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in experience_tags2[0:10]:
    exp=i.text
    experience_required2.append(exp)

# %%
#creating DataFrame 

df2= pd.DataFrame({"Job Title":job_title2,"Job Location":job_location2,"Company Name":company_name2,"Experience Required":experience_required2})
df2
# Out:
#                                            Job Title  \
# 0  Artificial Intelligence/Computer Vision Engine...
# 1          Data Activation Specialist - Adobe Target
# 2                                     Data Scientist
# 3                  Data Scientist - Engine Algorithm
# 4  Opening For Jr. Data Scientist with Tatras Dat...
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7  URGENT: Data Scientist | Gurugram | 5 Days Wor...
# 8                                     Data Scientist
# 9                              SE/SSE-Data Scientist
#
#                                         Job Location  \
# 0  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2                                  Temp. WFH - Noida
# 3  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 4                                        Delhi / NCR
# 5  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. ProductDescription
# 3. Price

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.flipkart.com/")

# %%
#Sending text to search bar

sunglass=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
sunglass.send_keys('Sunglasses')

# %%
#Clicking the search button
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
#Declaring required arrays

brand=[]
description=[]
price=[]
off=[]

# %%
#Page scroller count

for count in range(0,3):
    
    name=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    desc=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    cost=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")     #Finding Details of Brand,desciption, price and off
    less=driver.find_elements(By.XPATH,"//div[@class='_3Ay6Sb']")
    
    for j in name:
        brand.append(j.text)
    for j in desc:
        description.append(j.text)  
    for j in cost:                                     #Creating array of data
        price.append(j.text)
    for j in less:
        off.append(j.text)

# %%
 #next page driver  
    
next_page=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
next_page.click()

# %%
#Creating DataFrame of required data   
    
df=pd.DataFrame({"Brand ":brand[0:100],"Description": description[0:100],"Price": price[0:100], "Off ":off[0:100]})
df
# Out:
#             Brand                                         Description Price  \
# 0       LIZA ANGEL  Riding Glasses, Night Vision Spectacle Sunglas...  ₹129
# 1         Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹489
# 2        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...  ₹149
# 3   ROZZETTA CRAFT  UV Protection, Gradient Retro Square Sunglasse...  ₹521
# 4         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹599
# ..             ...                                                ...   ...
# 95       Elligator                UV Protection Round Sunglasses (54)  ₹286
# 96    CRYSTAL CART  Polarized, UV Protection, Gradient, Riding Gla...  ₹314
# 97   VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...  ₹806
# 98       New Specs   UV Protection Rectangular Sunglasses (Free Size)  ₹259
# 99      LIZA ANGEL  UV Protection, Polarized Rectangular Sunglasse...  ₹129
#
#        Off
# 0   87% off
# 1   38% off
# 2   75% off
# ...

# %% [markdown]
# Q.5. Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product%02reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKAR

# %% [markdown]
# Driver Initializtion and connecting to site

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_32\chromedriver.exe")
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %% [markdown]
# Declaring Required arrays for data storage

# %%
rating=[]
summary=[]
review=[]

# %%
#Page Scroller loop

# %%
start=0
end=10
for page in range(start,end):
    rate= driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rate[0:100]:
        rating.append(i.text)
        
for page in range(start,end):
    sum= driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for d in sum[0:100]:
        summary.append(d.text)
        
for page in range(start,end):
    rev= driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for d in rev[0:100]:
        review.append(d.text)

# %%
#Clicking the next page

# %%
next_button1= driver.find_element(By.XPATH,'//a[@class="_1LKTO3" and span="Next"]')
next_button1.click()
time.sleep(3)

# %%
#creating DataFrame 

df4= pd.DataFrame({"Rating":rating[0:100],"Review Summary":summary[0:100],"Full Review":review[0:100]})
df4
# Out:
#    Rating       Review Summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5    Worth every penny
# ..    ...                  ...
# 95      5   Highly recommended
# 96      5   Highly recommended
# 97      5     Perfect product!
# 98      4          Pretty good
# 99      5        Great product
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  It's my first time to use iOS phone and I am l...
# 96  What a camera .....just awesome ..you can feel...
# 97  Value for money\n5 star rating\nExcellent came...
# ...

# %% [markdown]
# Q.6.Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field. You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
#getting webdriver

driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_32\chromedriver.exe")
     
#getting webpage https://www.flipkart.com/
driver.get('https://www.flipkart.com/')

# %%
# closing the log-in page window
close=driver.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
close.click()

# %%
#entering "sneakers" in "search for products" field
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sneakers')

# %%
#clicking the Search button
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
#introducing list for brand, product description, price & discount
brand=[]
prod1=[]
prod2=[]
price=[]
discount=[]

# %%
# for scrapping data from different pages to get first 100 reviews, defining Start & End of the page
for page in range(0,3):
    
    for i in driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]'):
        brand.append(i.text)
        
# Scrapping product description from different pages 
for j in driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]'):
    prod1.append(j.text)
        
for c in driver.find_elements(By.XPATH,'//a[@class="IRpwTa _2-ICcC"]'):
    prod2.append(c.text)
prod=prod1+prod2

# %%
# Scrapping price from different pages 
for k in driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]'):
    price.append(k.text)
        
# Scrapping discount from different pages 
for l in driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]'):
    discount.append(l.text)

# %%
#scraping the required data from different pages
nxt_button=driver.find_elements(By.XPATH,'//a[@class="_1LKTO3"]')
try:
    driver.get(nxt_button[1].get_attribute('href'))
except:
    driver.get(nxt_button[0].get_attribute('href'))

# %%
Sneaker_data=pd.DataFrame({"Brand":brand[0:100],"Product Des[0:100]cription":prod[0:100],"Price":price[0:100],"Discount":discount[0:100]})
Sneaker_data
# Out:
#        Brand                         Product Des[0:100]cription Price Discount
# 0     Labbin                                   Sneakers For Men  ₹399  60% off
# 1    AIRBELL                                   Sneakers For Men  ₹859  71% off
# 2     Labbin                                   Sneakers For Men  ₹399  60% off
# 3     Shozie  PLANCK Smart Grey Lace-Ups Casuals Sneakers Sn...  ₹295  70% off
# 4        SFR  FAST Trenddy Tainer Lace-ups Sporty Casuals Sn...  ₹209  65% off
# ..       ...                                                ...   ...      ...
# 95        TR  Canvas Casual Partywear Outdoor Sneakers Shoes...  ₹494  67% off
# 96  Elevarse  Perfect Stylish Girls Casual Shoes Sneakers Fo...  ₹279  65% off
# 97    BRUTON              Mens Casual Sneakers Sneakers For Men  ₹688  84% off
# 98     Sparx                                   Sneakers For Men  ₹899  66% off
# 99    lejano                                   Sneakers For Men  ₹499  65% off
#
# [100 rows x 4 columns]

# %% [markdown]
# Q.7.Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon.Then set CPU Type filter to “Intel Core i7” After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop: 1. Title 2. Ratings 3. Price

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_32\chromedriver.exe")
driver.get("https://www.amazon.in/")

# %%
item = driver.find_element(By.ID,"twotabsearchtextbox")
item.send_keys('Laptop')

search=driver.find_element(By.CLASS_NAME,"nav-right")
search.click()

# %%
core= driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/li[12]/span/a/div")
core.click()

# %%
title=[]
rating=[]
price=[]

# %%
name= driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in name[0:10]:
    titlen=i.text
    title.append(titlen)
    
rate=driver.find_elements(By.XPATH,'//span[@class="a-size-base"]')
for i in rate[0:10]:
    star=i.text
    rating.append(star)
    
cash=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in cash[0:10]:
    cas=i.text
    price.append(cas)

# %%
df = pd.DataFrame({"Title":title,"Rating":rating,"Price":price})
df
# Out:
#                                                Title Rating     Price
# 0  Acer Predator Helios 500 Gaming Laptop (11Th G...    5.0  4,32,435
# 1  Acer Predator Helios 300 Gaming Laptop Intel C...    3.9  1,15,990
# 2  ASUS Zenbook Pro 14 Duo OLED (2022) Dual Scree...    3.7  2,14,990
# 3  Hp Envy 15- 11Th Gen Intel Core I9/32Gb/1Tb Ss...    4.7  1,87,990
# 4  Dell G15-5521 Gaming Laptop, i9-12900H, 16GB D...    3.1  1,81,833
# 5  Acer Predator Helios 300 Gaming Laptop Intel C...    3.9  1,49,990
# 6  ASUS ROG Strix Scar 17 SE (2022), 17.3" (43.94...    4.7  3,59,990
# 7  Acer Predator Helios 300 Gaming Laptop Intel C...    5.0  1,89,990
# 8  Dell G15-5520 Gaming Laptop, i9-12900H, 16GB D...    3.0  1,52,100
# 9  ASUS ROG Strix Scar 15 (2022), Intel Core i9-1...    4.2  3,12,990

# %% [markdown]
# Q.8. Write a python program to scrape data for Top 1000 Quotes of All Time. get the webpage https://www.azquotes.com/ Then scrap a) Quote b) Author c) Type Of Quotes

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_32\chromedriver.exe")
driver.get("https://www.azquotes.com/")

# %%
search7=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
search7.click()

# %%
quote=[]
aut=[]
toq=[]

# %%
start=0
end=10
for page in range(start,end):
    qut= driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in qut:
        quote.append(i.text)
        
for page in range(start,end):
    auth= driver.find_elements(By.XPATH,'//div[@class="author"]')
    for d in auth:
        aut.append(d.text)
        
for page in range(start,end):
    type= driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for d in type:
        toq.append(d.text)

# %%
next_button3= driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a")
next_button3.click()
time.sleep(3)

# %%
df8= pd.DataFrame({"Quote":quote[0:1000],"Author":aut[0:1000],"Type Of Quote":toq[0:1000]})
df8
# Out:
#                                                  Quote                Author  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# Q.9. Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_32\chromedriver.exe")
driver.get("https://www.jagranjosh.com/")

# %%
gk=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a")
gk.click()

# %%
time.sleep(4)

# %%
pm_list=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
pm_list.click()

time.sleep(4)

# %%
temp=driver.find_elements(By.XPATH,"//*[@id='itemdiv']/div[4]/span/div[2]/table/tbody/tr")

for i in temp:
    desc1=i.text
    desc.append(desc1)

# %%
name_list=[]
age_list=[]
comment_list=[]
term_list=[]

n=len(desc)

# %%
for i in range(1,n):

    details=desc[i].split("\n")
    name=details[1]               #Splitting data to bifurcate Name, birth-death, term of office and comment from whole list
    name_list.append(name)
    
    birth=details[2]
    age=birth.replace("(","")    #Replacing bracets of birth-death
    age_list.append(age.replace(")",""))
    
    comment=details[5:]
    comment_list.append(comment)
    
    term=details[3:5]
    term_list.append(term)

# %%
m=len(term_list)
final=term_list[m-1]
term_list[m-1]=final[0]
comment_list[m-1]=final[1]

#Creating DataFrame

df=pd.DataFrame({"Name " :name_list,"Born-Dead ": age_list,"Term of Office" : term_list,"Remarks" : comment_list})
df
# Out:
#                           Name   Born-Dead   \
# 0             Jawahar Lal Nehru   1889–1964
# 1     Gulzarilal Nanda (Acting)   1898-1998
# 2           Lal Bahadur Shastri   1904–1966
# 3   Gulzari Lal Nanda  (Acting)   1898-1998
# 4                 Indira Gandhi   1917–1984
# 5                 Morarji Desai   1896–1995
# 6                  Charan Singh   1902–1987
# 7                 Indira Gandhi   1917–1984
# 8                  Rajiv Gandhi   1944–1991
# 9                   V. P. Singh   1931–2008
# 10              Chandra Shekhar   1927–2007
# 11          P. V. Narasimha Rao   1921–2004
# 12         Atal Bihari Vajpayee  1924- 2018
# 13             H. D. Deve Gowda   born 1933
# 14           Inder Kumar Gujral   1919–2012
# 15         Atal Bihari Vajpayee   1924-2018
# 16               Manmohan Singh   born 1932
# 17                Narendra Modi   born 1950
#
#                                        Term of Office  \
# 0   [15 August 1947 to 27 May 1964, 16 years, 286 ...
# ...

# %% [markdown]
# Q.10. Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name ,Description and Price) from https://www.motor1.com/

# %%
driver = webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_32\chromedriver.exe")
driver.get("https://www.motor1.com/")

# %%
drop=driver.find_element(By.CLASS_NAME,"m1-hamburger-button")
drop.click()

# %%
feat= driver.find_element(By.XPATH,"/html/body/div[4]/div[1]/div[3]/ul/li[5]/a")
feat.click()

# %%
cars=driver.find_element(By.XPATH,"/html/body/div[3]/div[8]/div/div[1]/div[1]/div[2]/div/div[1]/h3/a")
cars.click()

car_name=[]
car_desc=[]
car_price=[]

carn= driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in carn:
    car_name.append(i.text)
    
card=driver.find_elements(By.TAG_NAME,"p")
for i in card:
    car_desc.append(i.text.replace("Price",""))
    
carp=driver.find_elements(By.TAG_NAME,"strong")
for i in carp:
    car_price.append(i.text)
    

#creating DataFrame 

df10=pd.DataFrame({"Car Name":car_name[0:50],"Description":car_desc[4:54],"Car Price":car_price[0:50]})
df10
